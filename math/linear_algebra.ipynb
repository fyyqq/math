# %%
import numpy
import math
from IPython.display import display, Math

# %% [markdown]
# ### ^ = Exponents

# %%
# symbols:  2^6 = 64
fn = numpy.power(2, 6)

2 * 2 * 2 * 2 * 2 * 2 # = 64
# Out:
# 64

# %% [markdown]
# ### √ = Square Root

# %%
# symbols: √ 25 = 5 ^ 5

numpy.sqrt(25) # = 5 ^ 5
numpy.sqrt(100) # = 10 ^ 10

5 * 5
10 * 10
# Out:
# 100

# %% [markdown]
# ### Logarithms

# %%
numpy.log2(64) # = 6
# 2 ^ 6
2 * 2 * 2 * 2 * 2 * 2

numpy.log2(32) # = 5
# 2 ^ 5
2 * 2 * 2 * 2 * 2

numpy.log2(16) # = 
# 2 ^ 4
2 * 2 * 2 * 2
# Out:
# 16

# %%
numpy.log10(100) # = 2
# 10 ^ 2
10 * 10

numpy.log10(1000) # = 3
# 10 ^ 3
10 * 10 * 10
# Out:
# 1000

# %% [markdown]
# ### e = 2.71828

# %%
e = 2.71828
numpy.power(e, 2)
# Out:
# 7.3890461584

# %% [markdown]
# ### Sequence Summation = Sum All Item

# %%
lists = [1, 2, 3, 4, 5]
print("list: ", lists)
display(Math('{n} = %g' %len(lists)))
display(Math('{ i = 1 } = From First Item'))
display(Math('\sum = Summation'))
display(Math('\sum_{i=1}^{n} a_i %g'))
# Out:
# list:  [1, 2, 3, 4, 5]
# $\displaystyle {n} = 5$
# $\displaystyle { i = 1 } = From First Item$
# $\displaystyle \sum = Summation$
# $\displaystyle \sum_{i=1}^{n} a_i %g$

# %% [markdown]
# ### Sequence Multiplication = Multiply All

# %%
display(Math(r'{{ i = 1 }} = From First Item'))
display(Math(r'\prod = Multipication'))
display(Math(r'\prod_{{ i = 1 }} ^ {{ n }} a_i'))
# Out:
# $\displaystyle {{ i = 1 }} = From First Item$
# $\displaystyle \prod = Multipication$
# $\displaystyle \prod_{{ i = 1 }} ^ {{ n }} a_i$

# %% [markdown]
# # <p style="color: magenta;">Linear Equation</p>

# %% [markdown]
# <i>
# 1. Eliminate 1 Variable
# <br>
# 2. Find Values of 1 Variable
# <br>
# 3. If Eliminate 1 number use (-)
# <br>
# 4. If Eliminate 1 variable use (/)
# </i>

# %% [markdown]
# ### Question
# x + y = 3
#
# x - y = 1
#
# #### Find ( x ):
#
# ( x + y ) + ( x - y ) = 3 + 1
#
# ( x + y ) + ( x - y ) = 4
#
# 2x = 4
#
# 2x / 2 = 4 / 2
#
# x = 2
#
# #### Find ( y ):
#
# 2 + y = 3
#
# y = 2 - 3
#
# y = 1
#
# #### Result:
#
# 2 + 1 = 3
#
# 2 - 1 = 1

# %% [markdown]
# ### Question
#
# 5x + 3y = 2
#
# 2x + 3y = 11
#
# ##### Find ( x ):
#
# ( 5x + 3y ) - ( 2x + 3y ) = 2 - 11
#
# 5x - 2x = -9
#
# -9 = 5x - 2x
#
# -9 = 3x
#
# -9 / 3 = 3x / 3
#
# x = -3
#
# ##### Find ( y ):
#
# 5(-3) + 3y = 2
#
# - 15 + 3y = 2
#
# 3y = - 15 + 2
#
# 3y = 17
#
# 3y / 3 = 17 / 3
#
# y = 17 / 3
#
# y = 3 ( 17 / 3 )
#
# y = 3 x 3 = 1
#
# y  =  17
#
# ##### Result:
#
# 5(-3) + 3(17 / 3) = 2
#
# 2(-3) + 3(17 / 3) = 11
#
# -15 + 17 = 2
#
# -6 + 17 = 11

# %% [markdown]
# ### Question
#
# -7x + 6y = -8
#
# 6x + 12y = 24
#
# ##### Find ( x ):
#
# (-7x + 6y = -8) x (2)
#
# 14x + 12y = 16
#
# 6x + 12y = 24
#
# (14x + 12y) + (6x + 12y) = 16 + 24
#
# 20x = 40
#
# 20x / 20 = 40 / 20
#
# x = 2
#
# ##### Find ( y ):
#
# 6(2) + 12y = 24
#
# 12 + 12y = 24
#
# 12y = 12 - 24
#
# 12y / 12 = 12 / 12
#
# y = 1
#
# ##### Result:
#
# -7(2) + 6(1) = -8
#
# 6(2) + 12(1) = 24
#
# 12 + 12 = 24
#
# -14 + 6 = -8

# %% [markdown]
# ### Question
#
# 4x - 2y = 4
#
# 5x + 3y = 16
#
# ##### Find ( x ):
#
# (4x - 2y = 4) * (3)
#
# (5x + 3y = 16) * (2)
#
# 12x - 6y = 12
#
# 10x + 6y = 32
#
# (12x - 6y) - (10x + 6y) = 12 + 32
#
# 12x + 10x = 44
#
# 22x = 44
#
# 22x / 22 = 44 / 22
#
# x = 2
#
# ##### Find ( y ):
#
# 5(2) + 3y = 16
#
# 10 + 3y = 16
#
# 3y = 10 - 16
#
# 3y = 6
#
# 3y / 3 = 6 / 3
#
# y = 2
#
# ##### Result:
#
#
# 4(2) - 2(2) = 4
#
# 5(2) + 3(2) = 16
#
# 8 - 4 = 4
#
# 10 + 6 = 16

# %% [markdown]
# ### Question
#
# 3x + 12y = 21
#
# 2x - 4y = 11
#
# ##### Find ( x ):
#
# (3x + 12y = 21) / (3)
#
# x + 4y = 7
#
# x + 4y = 7 - 4y
#
# x = 7 - 4y
#
# ##### Find ( y ):
#
# 2x - 4y = 11
#
# 2(7 - 4y) - 4y = 11
#
# 14 - (8y + 4y) = 11
#
# 14 - 12y = 11
#
# 12y = 11 - 14
#
# 12y / 12 = -3 / 12
#
# y = 1 / 4
#
# ##### Result:
#
# <b>(1) Result</b>
#
# 3x + 12( 1 / 4 ) = 21
#
# 3x + 3 = 21
#
# 3x = 21 - 3
#
# 3x / 3 = 18 / 3
#
# x = 6
#
# -------------------------
#
# 3(6) + 12( 1 / 4 ) = 21
#
# 18 + 3 = 21
#
# <b>(2) Result</b>
#
# 2(6) - 4(1 / 4) = 11
#
# 12 - 1 = 11

# %% [markdown]
# ### Question
#
# ax + by = 12
#
# x - 2by = -10
#
# ##### Find ( a, b ):
#
# x = 2
#
# y = 3
#
# a(2) + b(3) = 12
#
# 2(a) + 3(b) = 12
#
# 2 - 2b(3) = -10
#
# 2 - 6b = -10
#
# (2 - 2) - 6b = (-10 - 2)
#
# -6b / 6 = -12 / 6
#
# b = 2
#
# 2(a) + 3(2) = 12
#
# 2(a) + 6 = 12
#
# 2(a) + (6 - 6) = (12 - 6)
#
# 2(a) / 2 = 6 / 2
#
# a = 3
#
# ##### Result:
#
# <b>(1) Result</b>
#
# 3(2) + 2(3) = 12
#
# 6 + 6 = 12
#
# -------------------------
#
# <b>(2) Result</b>
#
# 2 - 2(2)(3) = -10
#
# 2 - 12 = -10

# %% [markdown]
# 3x + 6y = 12
# 5x - 8y = 2
#
# (3x + 6y = 12) * 5
# (5x - 8y = 2) * 3
#
# 15x + 30y = 60
# 15x - 24y = 6
#
# 30y / 30 = 60 / 30
#
# x = 2
#
# ------------------------
#
# 3(2) + 6y = 12
# 6 + 6y = 12
#
# 6y = 6 + 12
# 6y / 6 = 18 / 6
#
# y = 3
#
# --------------------------
#
# 3(2) + 6(3) = 12
# 6 - 18 = 12
#
# 5(2) - 8(3) = 2
# 10 - 24 = 14

# %% [markdown]
# ¹ ² ³ ⁴ ⁵ ⁶ ⁷ ⁸ ⁹
#
# m = intercept
# b = coefficient
#
# y = 2x - 4
# m = 2
# b = - 4
#
# x = 0
# y = 2(0) - 4
# y = 0 - 4
# y = -4
# (x¹, y¹) => (0, -4)
#
# x = 1
# y = 2(1) - 4
# y = 2 - 4
# y = -2
# (x², y²) => (1, -2)
#
# rise / run = y² - y¹ / x² - x¹
#
# y = -2 - (-4)
# y = 2a
#
# x = 1 - 0
# x = 1
#
# rise / run => 2 / 1

# %% [markdown]
# ¹ ² ³ ⁴ ⁵ ⁶ ⁷ ⁸ ⁹
#
# 2x + 5y = 19
# x - 2y = -4
#
# ##### eliminate (x)
#
# (x - 2y)² = (-4)²
#
# (2x + 5y) - (2x - 4y) = 19 - (- 8)
#
# ##### get (y)
#
# 5y - (-4y) = 19 + 8
#
# 5y + 4y = 27
#
# 9y = 27
#
# 9y / 9 = 27 / 9
#
# y = 3
#
# ##### get (x)
#
# x - 2³ = -4
#
# x - 6 = -4
#
# x = - 4 (- 6)
#
# x = - 4 + 6
#
# X = 2

# %% [markdown]
# ¹ ² ³ ⁴ ⁵ ⁶ ⁷ ⁸ ⁹
#
# y = 5 - 2x
#
# 4x + 3y = 13
#
# #### find (x) = 1
#
# 4x + 3 (5 - 2x) = 13
#
# 4x + 15 - 6x = 13
#
# -2x + 15 = 13
#
# -2x + 15 - 15 = 13 - 15
#
# -2x / 2 = -2 / 2
#
# x = 1
#
# #### find (y) = 3
#
# 4¹ + 3 (5 - 2x) = 13
#
# 4 + 15 - 6¹ = 13
#
# 4 + (15 - 6) = 13
#
# 4 + 9 = 13

# %% [markdown]
# ¹ ² ³ ⁴ ⁵ ⁶ ⁷ ⁸ ⁹
#
# 3x - 2y + 4z = 35 (a)
# -4x + y - 5z = -36 (b)
# 5x - 3y + 3z = 31 (c)
#
# b = (-4x + y - 5z = -36)² | -8x + 2y - 10z = -72
#
#     3x - 2y + 4z = 35 (a)
# +   -8x + 2y - 10z = -72 (b)
# (a) = -5x -6z = -37
#
# b = (-4x + y - 5z = -36)³ | -12x + 3y - 15z = -108
#
#     -12x + 3y - 15z = -108 (b)
# +   5x - 3y + 3z = 31 (c)
# (c) = -7x -12z = -77
#
#
# (-5x - 6z = -37)² | -10x -12z = -74
#
#     -10x - 12z = -74
# -   -7x - 12z = -77
# ==> -3x = 3
#
# -3x / 3 = 3 / 3
#
# x = -1
#
# -----------------------------------------------
#
# -5(-1) - 6z = -37 (a)
# 5 - 6z = -37
# 5 - 5 = -37 - 5
# -6z = -42
# -6z / -6 = -42 / -6
#
# z = 7
#
# -----------------------------------------------
#
# 3(-1) - 2y + 4(7) = 35 (a)
#
# -3 - 2y + 28 = 35
# 2y -3 + 28 = 35
# -2y + 25 = 35
# 25 - 25 = 35 - 25
# -2y = 10
# -2y / 2 = 10 / 2
#
# y = -5
#
# -----------------------------------------------
#
# 3(-1) - 2(-5) + 4(7) = 35 (a)
# -3 + 10 + 28 = 35

# %%
-3 + 10 + 28
# Out:
# 35

# %% [markdown]
# # <p style="color: mediumseagreen;">Eigenvalues and Eigenvectors</p>

# %% [markdown]
# <i>
# A : Square Matrix
# <br>
# [<br>
#     a   b<br>
#     c   d
# <br>]
# <br>
# <br>
# -λ : Lambda
# <br>
# <br>
# v : Eigenvector
# <br>
# <br>
# I : Matrix Identity
# <br>
# [<br>
#     1   0<br>
#     0   1
# <br>]
# <br>
# <br>
# Av = λv :  Eigenvalue λ
# <br>
# <br>
# det(A -  λI) = 0 : <br>
# <br>
# [<br>
#     (a-λ)   b<br>
#     c   (d-λ)
# <br>]
# <br>
# <br>
# Av = λv :  Eigenvalue λ
# <br>
# </i>

# %% [markdown]
# #### Find Eigenvalues (λ)
# ¹ ²
#
# A = [
#     4  -5
#     2  -3
# ]
#
# Av = λv == A
# Av = λv | (A - λI)v = 0
#
# λ = det(A - λI) = 0
# [
#     (4 - λ)  -5
#     2  (-3 - λ)
#
# ] = (4 - λ) (-3 - λ) + 10
#
# det (
#     (4 - λ)   -5
#        2      (-3 - λ)
# )
#
# det(A - λI)
# (
#     a   b
#     c   d
# )
# ad - bc :
# (4 - λ) (-3 - λ) - (-5)(2)
# (4 - λ) (-3 - λ) - (-10)
# (4 - λ) (-3 - λ) + 10
#
# ad : (4 - λ) (-3 - λ)
#
# 4 x (-3) = -12
# 4 x (-λ) = -4λ
# -λ x (-3) = +3λ
# -λ x (-λ) = +λ²
#
# (4 - λ) (-3 - λ) = -12 - 4λ + 3λ + λ²
# λ² - 4λ + 3λ - 12
# λ² - λ - 12
#
# λ² - λ - 12 + 10
# λ² - λ - 2 = 0
#
# λ² - λ - 2 = (λ + 1) (λ - 2)
# λ x λ = λ²
# λ x -2 = -2λ
# 1 x λ = λ
# 1 x -2 = -2
# λ² - 2λ + λ -2
# λ² - λ - 2
# => (λ + 1) (λ - 2)
# => λ (λ - 2)
# => (λ) (-1)
# => λ = -1 | λ = 2
#
# -------------------------------
# => λ = -1
# => λ = 2
#
# (4 - -1) (-3 - (-1)) + 10
# (4 - -1) (-3 + 1) + 10
# (5) (-2) + 10 = 0
# ------------------------------
# (4 - 2) (-3 - 2) + 10
# (2) (-5) + 10 = 0

# %% [markdown]
# #### Find Eigenvalues & Eigenvectors
# ¹ ² | λ
#
# Av = λv
#
# A = [
#     4   -5
#     2   -3
# ]
#
# I = [
#     1   0
#     0   1
# ]
#
# det(A - λI) :
# (
#     a   b
#     c   d
# ) = (ad - bc)
#
# det(A - λI) :
# [
#     (4-λ)   -5
#     2       (-3-λ)
# ]
#
# # Find Eigenvalues
#
# # ad - bc
#
# (4-λ) * (-3-λ) - (-5) (2)
# 4(-3) = -12
# 4(-λ) = -4λ
# -λ(-3) = 3λ
# -λ(-λ) = λ²
#
# 5 * 2 = 10
# # - 4λ + 3λ + λ² - 12
#
# - λ + λ² (- 12 + 10)
# ### λ² - λ - 2
#
# ### (λ - 1) (λ + 2)
# λ(λ) = λ²
# λ(2) = 2λ
# -1(λ) = -λ
# -1(2) = -2
#
# => λ² + 2λ - λ - 2
# (2 - 1)λ = -1λ
# => λ² - λ - 2
#
# # λ¹ = 1
# # λ² = 2
#
# # Find Eigenvectors
#
# λ¹ = 1
# λ² = 2
#
# # A - λ¹I
#
# A = [
#     4   -5
#     2   -3
# ]
#
# λ¹I = [
#     1   0
#     0   1
# ]
#
# [
#     4   -5
#     2   -3
# ] - 1(λ¹) [
#     1   0
#     0   1
# ] [
#     x¹
#     x²
# ] = [
#     0
#     0
# ]
#
# a => 4 -1(1) = 3
# b => -5 -1(0) = -5
# c => 2 -1(0) = 2
# d => -3 -1(1) = -4
#
# => [
#     3   -5  |   x¹  |   0
#     2   -4  |   x²  |   0
# ]
#
# => 3x¹ -5x² = 0
# => 2x¹ -3x² = 0

# %% [markdown]
# λ¹²
#
# A = [
#     7    3
#     3   -1
# ]
#
# I = [
#     1(-λ)   0
#     0   -1(-λ)
# ]
#
# AI = [
#     (7-λ)   3
#     3   (-1-λ)
# ]
#
# # Find Eigenvalues
#
# ab - cd = 0 :
# (7-λ) (-1-λ) - (3) (3)
# 7 * -1  = -7
# 7 * -λ  = -7λ
# -λ & -1 = λ
# -λ & -λ = λ²
# 3 * 3   = 9
#
# -7 - 7λ + λ + λ² - 9
# -7 - 9   = 16
# -7λ + λ  = -6λ
#
# λ² - 6λ + 16 = 0 | (λ - 8) (λ + 2)
# # (λ - 8) (λ + 2)
# λ * λ  = λ²
# λ * 2  = 2λ
# -8 * λ = -8λ
# -8 * -2 = -16
#
# λ² + 2λ - 8λ - 16
# λ² - 6λ + 16
#
# # Eigenvalues :
# λ¹ = 8
# λ² = -2
#
# -------------------------------------------
#
# # Find Eigenvectors
#
# λ¹ = 8
# λ² = -2
#
# (A - λI)v = 0
#
# A = [
#     7-λ     3
#     3       -1-λ
# ] = [
#     7-8     3
#     3       -1-8
# ] = [
#     -1     3
#     3      -9
# ]
#
# [
#     -1     3    |   0
#     3      -9    |   0
# ]
#
# 3R¹ + R² => R²
#
# [
#     -1(3) + 3 = 0       3(3) + -9 = 0    |   0
#           3                   -9         |   0
# ] = [
#     x¹      x²
#     -1      3    |   0
#     0       0    |   0
# ]
#
# -x¹ + 3x² = 0
# 3x² = x¹
# 1x + x² = 1
# 3(1) = x¹
#
# ______________________________________________
#
# -1x¹ +  3x² = 0
# 3x¹  + -9x² = 0
#
# -1x¹ + 3x² = 0
# -1x¹ + 3x² + 1x¹ = 0 + 1x¹
# 3x² = 1x¹
# 1x¹ = 3x²
# # x¹ = 3x²

# %%
-1 + 3 + 1
# Out:
# 3

# %% [markdown]
# λ¹²
#
# A-λ = [
#     5-λ   2
#     -9   6-λ
# ]
#
# λ¹ = -3
# λ² = 4
#
# A-v¹ = [
#     -5-(-3)  +   2
#     -9       +   6-(-3)
# ]
#
# A-v¹ = [
#     -2x¹      2x²
#     -9x¹      9x²
# ]
#
# -2x¹ + 2x² = 0
# -9x¹ + 9x² = 0
#
# Av¹ = [
#     -5     2
#     -9     6
# ] [
#     1
#     1
# ]
# = [
#     -3
#     -3
# ]

# %%
-5 + 3
# Out:
# -2

# %% [markdown]
# # Av = λv
#
# λ¹²
#
# # A - λI = 0
#
# A = [
#     2   3
#     2   1
# ]
#
# I = [
#     1   0
#     0   1
# ]
#
# det(A - λI) = [
#     (2-λ)   3
#     2       (1-λ)
# ]
#
# # Eigenvalues
#
# ad - bc :
# (2-λ) (1-λ) - (3) (2) = 0
# 2 * 1 = 2
# 2 * -λ = -2λ
# -λ * 1 = -λ
# -λ * -λ = λ²
# 3 * 2 = 6
#
# 2 - 2λ - λ - λ² - 6
# λ² - λ - 2λ - 6 + 2
# λ² - 2λ - λ - 4
# λ² - (-2 + 1)λ - 4
# λ² + 3λ - 4
# # λ² + 3λ - 4
#
# ## (λ - 4) (λ + 1)
#
# λ² + λ - 4λ - 4
# λ² + (1 - 4)λ - 4
# λ² - 3λ - 4
#
# # Eigenvectors
#
# (A - λI)v
#
# λ¹ = -4
#
# A - λ¹ = [
#     2   3
#     2   1
# ] - (-4) [
#     1   0
#     0   1
# ]
#
# A - λ¹ = [
#     (2 + 4)   3
#     2   (1 + 4)
# ]
#
# A - λ¹ = [
#     6   3   |   x¹  |   0
#     2   5   |   x²  |   0
# ]
#
# 6x¹ + 3x² = 0
# 2x² + 5x² = 0
#
# 6   3   |   0
# 2   5   |   0
#
# # R2 = R2 - 1/3R1
#
# R1 = 6  |   3
# R2 = 2  |   5
#
# R1 * 1/3 :
# 6 * 1 / 3 = 2
# 3 * 1 / 3 = 1
#
# R2 - 1/3R1 :
# 2 - 2 = 0
# 5 - 1 = 4
#
# 6   3   |   0
# 0   4   |   0
#
# 6x¹ + 3x² = 0
# 4x² = 0
# # x² = 0
#
# 6x¹ + 3(0) = 0
# 6x¹ + 0 = 0
# 6x¹ = 0
# # x¹ = 0
#
# v¹ = [
#     0
#     0
# ]
#
# λ² = 1
#
# A - λ¹ = [
#     2   3
#     2   1
# ] - (1) [
#     1   0
#     0   1
# ]
#
# A - λ¹ = [
#     (2-1)   3
#     2   (1-1)
# ]
#
# A - λ¹ = [
#     1   3
#     2   0
# ]
#
# 1x¹ + 3x² = 0
# 2x¹ + 0x² = 0
#
# R2 => R2 - 2R1
#
# R1 = 1  |   3
# R2 = 2  |   0
# 2R1 = 2  |   6
# R2 - 2R1 = 2-2  |   -6
# R2 => 0  |   -6
#
# [
#     1   3
#     0   -6
# ]
#
#
# x¹ + 3x² = 0
# -6x² = 0
#
# x¹ = -3x²
#
# v²
# t [
#     -3
#     1
# ]

# %% [markdown]
# λ¹²
#
# A = [
#     a   b   c
#     d   e   f
#     g   h   i
# ]
#
# A = [
#     4   1   1
#     2   3   1
#     1   1   2
# ]
#
# det(A - λI) = [
#     (4-λ)   1       1
#     2       (3-λ)   1
#     1       1       (2-λ)
# ]
#
#     a       |   e       f         |  -b   |   d   f       |   +c   |   d    e
#             |   h       i         |       |   g   i       |        |   g    h
#
#     (4-λ)   |   (3-λ)     1       |  -1   |   2   1       |   +1   |   2    (3-λ)
#             |   1         (2-λ)   |       |   1   (2-λ)   |        |   1    1
#
# [
#     (3-λ)     1
#     1         (2-λ)
# ]
#
# ##### Find Eigenvalues
#
# ei - fh :
# (3-λ) (2-λ) - (1) (1)
# 3 * 2 = 6
# 3 * -λ = -3λ
# -λ * 2 = -2λ
# -λ * -λ = -λ²
# - 1 * 1 = -1
#
# 6 - 3λ - 2λ - λ² - 1
# 6 - 3λ - 2λ - λ² - 1
# 6 - 5λ + λ² - 1
# # λ² - 5λ + 5
#
# (λ + 1) (λ - 5)
# λ * λ = λ²
# λ * -5 = -5λ
# 1 * λ = λ
# 1 * -5 = -5
# λ² - 5λ + 5
#
# [
#     2   1
#     1   (2-λ)
# ]
#
# di - fg :
# (2) (2-λ) - (1) (1)
# (2) (2-λ) - 1
# 2 * 2 = 4
# 2 * -λ = -2λ
# -1 * 1 = -1
# 4 - 2λ - 1
# # 3 - 2λ
#
# dh - eg :
# (2) (1) - (3-λ) (1)
# 2 - (3 - λ) * (1)
# 2 - 3 + λ * (1)
# -1 + λ
# # λ - 1
# _____________________________________________
#
# (4-λ) (λ² - 5λ + 5) - 1(3 - 2λ) + 1(λ - 1) = 0
# (4-λ) (λ² - 5λ + 5) - (3 + 2λ) + (λ - 1) = 0
# (4-λ) (λ² - 5λ + 5)
# 4 * λ² = 4λ²
# 4 * -5λ = -20λ
# 4 * 5 = 20
# -λ * λ² = -λ³
# -λ * -5λ = +5λ²
# -λ * 5 = -5λ
# -------------------
# -1(3 + 2λ) + 1(λ - 1)
# - 3 - 2λ + λ - 1
# (- 3 - 1) (- 2λ + λ)
# # - 4 - λ
#
#
# 4λ² - 20λ + 20 - λ³ + 5λ² - 5λ - 4 - λ
# (4λ² + 5λ²) (- 20λ - 5λ) + (20 - 4) - (λ³ - λ)
# 9λ² - 25λ + 16 - λ³
# # -λ³ + 9λ² - 25λ + 16 = 0
#
# ## (λ - 4) (λ + 2) (λ - 1) = 0
# λ * λ = λ²
# λ * 2 = 2λ
# -4 * λ = -4λ
# -4 * 2 = -8
#
# λ² + (2λ - 4λ) - 8
# λ² + 2λ - 8
#
# # (λ² + 2λ - 8) (λ - 1)
# λ² * λ = λ³
# λ² * -1 = -λ²
# 2λ * λ = 2λ²
# 2λ * -1 = 2λ
# -8 * λ = -8λ
# -8 * -1 = 8
#
# λ³ - λ² + 2λ² + 2λ - 8λ + 8
# λ³ - (λ² + 2λ²) + (2λ - 8λ) + 8
# (λ - 4) (λ + 2) (λ - 1) = λ³ - 3λ² - 6λ + 8
#
# ##### Find Eigenvalues
#
# λ¹ = 4
# λ² = -2
# λ³ = 1
#
# (A - λI)v = 0
#
# A - λI = [
#     4-4   1     1
#     2     3-4   1
#     1     1     2-4
# ]
#
# 3R¹ + R² => R²
#
# A = [
#     0     1     1
#     2     -1    1
#     1     1     -2
# ]

# %% [markdown]
# λ¹²³
#
# A - λI = [
#     a   b   c
#     d   e   f
#     g   h   i
# ]
#
# A - λI = [
#     2-λ   1     3
#     1     2-λ   3
#     3     3     20-λ
# ]
#
# a    |       ei - fh       |  b  |     di - fg    |  c  | dh - eg = 0
# 2-λ  | (2-λ) (20-λ) - 3(3) | - 1 | (20-λ)1 - 3(3) | + 3 | 3(1) - 3(2-λ) = 0
#
# ei - fh :
# (2-λ) (20-λ) - 3(3)
# 2 * 20 = 40
# 2 * -λ = -2λ
# -λ * 20 = -20λ
# -λ * -λ = -λ²
# 3 * 3 = 9
#
# 40 - 2λ - 20λ - λ² - 9
# 40 - 2λ - 20λ - λ² - 9
# 40 - 9 + 22λ - λ²
# ei - fh : 31 + 22λ - λ²
#
# 2-λ  | λ² + 22λ + 31 | - 1 | (20-λ)1 - 3(3) | + 3 | 3(1) - 3(2-λ) = 0
#
# di - fg :
# (20-λ)1 - 3(3)
# 20 - λ - 9
# 20 - 9 - λ = 11
# di - fg : 11 - λ
#
# 2-λ  | λ² + 22λ + 31 | - 1 | 11 - λ | + 3 | 3(1) - 3(2-λ) = 0
#
# dh - eg :
# 3(1) - 3(2-λ)
# 3 * 1 = 3
# 3 * 2 = 6
# 3 * -λ = -3λ
# 3 - 6 - 3λ
# dh - eg : -3 - 3λ
#
# 2-λ  | λ² + 22λ + 31 | - 1 | 11 - λ | + 3 | -3 + 3λ = 0
#
# (2-λ) (λ² + 22λ + 31)
# 2 * λ² = 2λ²
# 2 * -22λ = -44λ
# 2 * -31 = -62
# -λ * λ² = -λ³
# -λ * 22λ = 22λ²
# -λ * 31 = -31λ
# # 2λ² - 44λ + 62 - λ³ + 22λ² - 31λ
#
# (-1) (11 - λ)
# -1 * 11 = -11
# -1 * -λ = λ
# # -11 + λ
#
# (3) (-3 + 3λ)
# 3 * -3 = -9
# 3 * 3λ = 9λ
# # -9 + 9λ
#
# 2λ² - 44λ + 62 - λ³ + 22λ² - 31λ - 11 + λ - 9 + 9λ
# (2λ² + 22λ²) - (- 44λ - 31λ + λ + 9λ) + (62 - 9 - 11) - λ³
# 24λ² - (- 44λ - 31λ + λ + 9λ) + (62 - 9 - 11) - λ³
# 24λ² - 65λ + 42 - λ³
# -λ³ + 24λ² - 65λ + 42
# # λ³ - 24λ² + 65λ - 42
#
# # (λ - 1) (λ - 2) (λ - 21)
# λ¹ = 1
# λ² = 2
# λ³ = 21
#
# λ * λ = λ²
# λ * -2 = -2λ
# -1 * λ = -λ
# -1 * -2 = 2
#
# λ² - 2λ - λ + 2
# λ² - 3λ + 2
#
# (λ² - 3λ + 2) (λ - 21)
# λ² * λ      = λ³
# λ² * -21    = -21λ²
# -3λ * λ     = -3λ²
# -3λ * -21   = 63λ
# 2 * λ       = 2λ
# 2 * -21     = -24
#
# λ³ - 21λ² - 3λ² + 63λ + 2λ - 24
# # λ³ - 24λ² + 65λ - 4
#
# # Eigenvectors = row below 1 need to 0 values
# λ¹ = 1
# λ² = 2
# λ³ = 2
#
# (A - λI)x = 0
#
# λ¹ = 1
# A - λ¹I = [
#     2-λ¹   1      3         |   x¹      0
#     1      2-λ¹   3         |   x²  =   0
#     3      3      20-λ¹     |   x³      0
# ] = [
#     1   1   3   |   0
#     1   1   3   |   0
#     3   3   19  |   0
# ]
#
# R2 => R2 - R1
# R3 => R3 - 3R1
#
# [
#     1     1     3     |   0
#     1-1   1-1   3-3   |   0
#     3-3   3-3   19-9  |   0
# ] = [
#     1   1   3   |   0
#     0   0   0   |   0
#     0   0   10  |   0
# ]
#
# R3 <=> R2
# [
#     x1  x2  x3
#     1   1   3   |   0
#     0   0   10  |   0
#     0   0   0   |   0
# ]
#
# 10x3 / 10 = 0 / 10
# x3 = 0
#
# x1 + x2 = 0
# x1 = -x2
#
# x1 = 1
# x2 = -1
# x3 = 0
#
# λ¹v = [
#     1
#     -1
#     0
# ]
# __________________________________________
# λ² = 2
#
# A - λ¹I = [
#     2-λ¹   1      3         |   x¹      0
#     1      2-λ¹   3         |   x²  =   0
#     3      3      20-λ¹     |   x³      0
# ] = [
#     2-2   1     3       |   0
#     1     2-2   3       |   0
#     3     3     20-2    |   0
# ]
#
# [
#     0   1   3     |   0
#     1   0   3     |   0
#     3   3   18    |   0
# ]
#
# R1 <=> R2
#
# [
#     1   0   3     |   0
#     0   1   3     |   0
#     3   3   18    |   0
# ]
#
# R3 => R3 - 3R1
#
# [
#     1     0     3    |   0
#     0     1     3    |   0
#     0     3     9    |   0
# ]
#
# R3 => R3 - 3R2
#
# [
#     x1    x2    x3
#     1     0     3    |   0
#     0     1     3    |   0
#     0     0     0    |   0
# ]
#
# x2 + 3x3 = 0
#
# x2 = 3x3
#
# x3 = 1
#
# x2 = -3(1) = -3
#
# x1 + 3x3 = 0
# x1 + 3(1) = 0
# x1 = -3
#
# λ²v = [
#     -3
#     -3
#     0
# ]

# %% [markdown]
# <h2 style="color: red;">Matrix Decompositions (LU Decompositions)</h2>
#
# <p>Step By Step :<p>
# <ul>
#     <li>Ax = b</li>
#     <span>=></span>
#     <small style="color: mediumseagreen; font-style: italic;">Matrix and Result</small>
#     <li>LUx = b</li>
#     <span>=></span>
#     <small style="color: mediumseagreen; font-style: italic;">Calculate Lower Matrix / Eliminate (L)</small>
#     <li>A = LU</li>
#     <span>=></span>
#     <small style="color: mediumseagreen; font-style: italic;">Analyse Lower (L) & Upper (U) of matrix</small>
#     <li>LZ = b</li>
#     <span>=></span>
#     <small style="color: mediumseagreen; font-style: italic;">Analyse Lower (L) & Upper (U) of matrix</small>
#     <li>UX = z</li>
#     <small style="color: mediumseagreen; font-style: italic;">Eliminate Upper (U)</small>
# </ul>

# %% [markdown]
# λ¹²³
#
# x¹ + 2x² + 3x³ = 9
# 4x¹ + 5x² + 6x³ = 24
# 3x¹ + x² - 2x³ = 4
#
# [
#     1   2   3   |   x¹  |   9
#     4   5   6   |   x²  |   24
#     3   1   -2  |   x³  |   4
# ]
#
# A = [
#     1     0     0
#     L21   1     0
#     L31   L23   1
# ] * [
#     u11     u12     u13
#     0       u22     u23
#     0       0       u33
# ]
#
# L21 = -m21
# L31 = -m31
# L32 = -m32
#
# R2 => R2 - 4/1R1
# R3 => R3 - 3/1R1
#
# 4 - (4/1 * 1) = 0
# 5 - (4/1 * 2) = -3
# 6 - (4/1 * 3) = -6
#
# 3 - (3/1 * 1) = 0
# 1 - (3/1 * 2) = -5
# -2 - (3/1 * 3) = -11
#
# [
#     1   2    3
#     0   -3   -6
#     0   -5   -11
# ]
#
# R3 => R3 - 5/3R2
#
# [
#     1   2    3
#     0   -3   -6     =   U
#     0   0    -1
# ]
#
# M21 = -4
# M31 = -3
# M32 = -5/3
#
# L21 = 4
# L31 = 3
# L32 = 5/3
#
# L = [
#     1   0     0
#     4   1     0
#     3   5/3   1
# ]
#
# A = [
#     1   2   3
#     4   5   6
#     3   1   -2
# ]
# L = [
#    1   0     0
#     4   1     0
#     3   5/3   1
# ]
# U = [
#     1   2   3
#     0   -3  -6
#     0   0   -1
# ]
#
# LZ = B [
#    1   0     0   |  z1      9
#    4   1     0   |  z2  =   24
#    3   5/3   1   |  z3      4
# ]
#
# 4z1 + 1z2 = 24
# 4(9) + z2 = 24
# 36 + z2 = 24
# z2 = 24 - 36
# z2 = -12
#
# 3z1 + 5/3(z2) + z3 = 4
# 3(9) + 5/3(-12) + z3 = 4
# 27 + 5(-4) + z3 = 4
# 27 - 20 + z3 = 4
# 7 + z3 = 4
# z3 = 4 - 7
# z3 = -3
#
# z1 + z2 + z3 = ???
# z1 = 9
# z2 = -12
# z3 = -3
#
# Ux = Z
# [
#     1   2   3   |  x1     9
#     0   -3  -6  |  x2  =  -12
#     0   0   -1  |  x3     -3
# ]
#
# -1x3 = -3
# -x3 = 3
#
# -3x2 - 6x3 = -12
# -3x2 - 6(3) = -12
# -3x2 - 18 = -12
# -3x2 = -12 + 18
# -3x2 = 6
# -3x2 / 3 = 6 / 3
# x2 = -2
#
# 1x1 + 2x2 + 3x3 = 9
# x1 + 2(-2) + 3(3) = 9
# x1 - 4 + 9 = 9
# x1 - 4 = 0
# x1 = 4
#
# x1 = 4
# x2 = -2
# x3 = 3

# %% [markdown]
# λ¹²³
# L = Lower
# U = Upper
#
# 6x1 + 18x2 + 3x3 = 3
# 2x1 + 12x2 + x3 = 9
# 4x1 + 15x2 + 3x3 = 0
#
# Ax = b
# LUx = b
# A = LU
# LZ = b
# Ux = z
#
# A = [
#     6   18   3
#     2   12   1
#     4   15   3
# ]
#
# L = [
#     1       0       0
#     L21     1       0
#     L31     L32     1
# ]
#
# U = [
#     u11   U12    U13
#     0     U22    U23
#     0     0      U33
# ]
#
# L21 = -m21
# L31 = -m31
# L32 = -m32
#
# # Elimination L
#
# Ax = b
# [
#     6   18   3  |   3
#     2   12   1  |   9
#     4   15   3  |   0
# ]
#
# R2 => R2 - 2/6R1
#
# 2 - ((2/6) * 6) = 0
# 12 - ((2/6) * 18) = 6
# 1 - ((2/6) * 3) = 0
#
# R3 => R3 - 4/6R1
#
# 4 - ((4/6) * 6) = 0
# 15 - ((4/6) * 18) = 3
# 3 - ((4/6) * 3) = 1
#
# U = [
#     6   18   3
#     0   6    0
#     0   3    1
# ]
#
# R3 => R3 - 3/6R2
#
# 3 - ((3/6) * 6) = 0
#
# U = [
#     6   18   3
#     0   6    0
#     0   0    1
# ]
#
# -m21 = 2/6 = -1/3
# -m31 = 4/6 = -2/3
# -m32 = 3/6 = -1/2
#
# L21 = 1/3
# L31 = 2/3
# L31 = 1/2
#
# A = LU
# [
#     6   18   3
#     2   12   1
#     4   15   3
# ] = [
#     1     0     0
#     1/3   1     0
#     2/3   1/2   1
# ]
#
# U = [
#     6   18   3
#     0   6    0
#     0   0    1
# ]
#
# Lz = b
# [
#     1     0     0   |   z1      3
#     1/3   1     0   |   z2  =   9
#     2/3   1/2   1   |   z3      0
# ]
#
# z1 = 3
#
# 1/3z1 + 1 = 9
# 1 + z2 = 9
# z2 = 9 - 1
# z2 = 8
#
# 2/3z1 + 1/2z2 + 1z3 = 0
# 2/3(3) + 1/2(8) + z3 = 0
# 2 + 4 + z3 = 0
# 6 + z3 = 0
# z3 = 0 - 6
# z3 = -6
#
# z1 = 3
# z2 = 8
# z3 = -6
#
# Ux = z
# [
#     6   18   3  |   x1      3
#     0   6    0  |   x2  =   8
#     0   0    1  |   x3      -6
# ]
#
# x3 = -6
#
# 6x2 / 6 = 8 / 6
# x2 = 4/3
#
# 6x1 + 18(4/3) + 3(-6) = 3
# 6x1 + 6(4) - 18 = 3
# 6x1 + 24 - 18 = 3
# 6x1 + 6 = 3
# 6x1 = 3 - 6
# 6x1 / 6 = 3 - 6
# x1 = -3 / 6
# x1 = -1 / 2
#
# x1 = -1 / 2
# x2 = 4/3
# x3 = -6

# %%
28 / 7
# Out:
# 4.0
