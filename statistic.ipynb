# %%
import numpy
import pandas
import matplotlib.pyplot as pylot
import scipy.stats as stat
import seaborn

# %%
rataan1 = 50
rataan2 = 65

sd = 5

sample1 = 50
sample2 = 40

# %%
test = numpy.random.randn(sample1)
test
# Out:
# array([ 2.01905944, -0.77402629, -0.98818719, -1.03376954,  0.44338616,
#        -0.35225767,  1.37584215, -0.15363999,  0.01136575, -0.23650223,
#        -0.18401315,  1.21032142,  0.1622014 ,  0.20394387,  2.20816666,
#         1.87961942,  1.33248984, -0.56556934,  0.31561913,  1.42670663,
#        -0.35650083,  0.55443202,  0.14046951,  1.66003168, -1.29228016,
#         0.353971  , -0.20324297,  1.42625564, -0.7315969 ,  1.84023988,
#        -0.92758914,  1.60784638,  0.08581984, -0.42604408, -0.32762417,
#        -0.21189177, -0.55481901,  0.33006115, -1.16021709,  0.51788984,
#         0.1558648 ,  0.77055573, -1.9044827 ,  0.04744829,  0.59303133,
#        -1.03168415, -0.59708767, -1.23723993, -1.46921352, -0.06335777])

# %%
print(test.size)
pylot.plot(test)
pylot.show()
# Out:
# 50

# %%
seaborn.distplot(test, hist=True)
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_10960\3201722898.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   seaborn.distplot(test, hist=True)
# <Axes: ylabel='Density'>

# %% [markdown]
# Generate Data

# %%
data1 = numpy.random.randn(sample1) * sd + rataan1
data2 = numpy.random.randn(sample2) * sd + rataan2
print(sample1, sample2)
print(rataan1, rataan2)
print(sd)

kelompok_data = [sample1, sample2]

batas = [numpy.min(numpy.hstack((data1, data2))), numpy.max(numpy.hstack((data1, data2)))]
batas
# Out:
# 50 40
# 50 65
# 5
# [41.75380204545614, 73.85690880648846]

# %%
pylot.figure(figsize=(7, 5))

a  = seaborn.distplot(data1, hist=False, label="Data 1")
b  = seaborn.distplot(data2, hist=False, label="Data 2")

a.set(xlabel='Data', ylabel='Density')
pylot.grid()
pylot.legend()
pylot.show()
print(data1, f"\nlen: {data1.size}\n", f"min: {numpy.min(data1)}\n", f"max: {numpy.max(data1)}")
print(data2, f"\nlen {data2.size}\n", f"min: {numpy.min(data2)}\n", f"max: {numpy.max(data2)}")
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_10960\2045146540.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   a  = seaborn.distplot(data1, hist=False, label="Data 1")
# C:\Users\User\AppData\Local\Temp\ipykernel_10960\2045146540.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   b  = seaborn.distplot(data2, hist=False, label="Data 2")
# [50.77669776 41.75380205 55.70097709 50.18139317 47.11379645 56.07891674
#  52.69797534 57.6732739  51.10745586 51.84993183 45.57359722 56.06468161
#  48.01740686 60.11529813 60.68528486 45.66421845 57.86323222 55.03598866
#  52.57634758 50.62424544 49.07208648 54.02404882 45.69704495 49.16462384
#  52.15982295 51.82659706 51.91536924 43.8390061  45.46762042 56.37781523
#  46.09283974 51.20250544 48.16642162 53.38869925 48.49209617 51.46337593
#  59.6686131  49.13658087 47.1958424  51.26860521 58.16627609 50.72703228
#  52.26194832 47.52467024 49.7494873  47.95058488 45.62563533 54.0138368
#  56.23683523 50.36894819]
# len: 50
#  min: 41.75380204545614
#  max: 60.68528486080642
# [67.26535232 63.95792135 55.85150876 65.2559658  68.70560058 66.97738844
#  70.80465976 66.8805664  55.62452901 70.86092808 64.73899711 69.07106616
#  65.60964577 61.13784239 62.55354025 70.48346808 61.00506209 57.57789925
#  70.59118833 66.81970702 64.75724668 66.81319612 66.36687709 64.69172857
#  73.85690881 63.2533696  62.28707144 61.33089037 62.87100335 64.94088565
#  70.49888961 66.39463776 61.03910926 68.63985215 60.92199463 57.22154119
#  68.89081565 65.8241657  65.16841802 59.79478863]
# len 40
#  min: 55.62452901022567
#  max: 73.85690880648846

# %%
fig, ax = pylot.subplots(1, 2, figsize=(7, 5), dpi=150)

ax[0].violinplot(data1)
ax[0].plot(1 + numpy.random.randn(sample1) / 10, data1, 'o', color="green")
ax[0].set_ylim(batas)

ax[1].violinplot(data2)
ax[1].plot(1 + numpy.random.randn(sample2) / 10, data2, 'o', color="blue")
ax[1].set_ylim(batas)

t, p = stat.ttest_ind(data1, data2)

sigtxt = ('', ' Tidak')
pylot.title("Dua Kelompok {} berbeda secara signifikan t({}) = {}, p = {}".format(sigtxt[int(p > .05)], sum(kelompok_data) - 2, numpy.around(t, 2), numpy.around(p, 6)))

pylot.show()
