# %%
import numpy
import pandas
import matplotlib.pyplot as pylot
import scipy.stats as stat
import seaborn

# %%
rataan1 = 50
rataan2 = 65

sd = 5

sample1 = 50
sample2 = 40

# %%
test = numpy.random.randn(sample1)
test
# Out:
# array([ 0.1747275 ,  0.40000658, -2.72458363,  2.79617019,  1.7065786 ,
#        -0.60176376, -0.60567895,  0.92883461,  1.44155075, -0.85697797,
#        -0.44547269, -0.03133147, -2.49265783, -0.01415085, -0.63219416,
#        -1.11935781, -1.68326247,  0.8930084 , -2.77091399,  0.13914685,
#        -0.72290579, -1.49728139, -1.26073793, -0.09254333, -1.07495364,
#        -1.00452677,  1.2933017 ,  1.57926583, -0.54964747, -0.96416167,
#        -0.95810178,  0.63920939, -1.06111347,  1.18994818, -0.8775855 ,
#        -0.61532544,  0.74328403,  0.41717266,  0.17110021, -2.65712173,
#         0.62588336, -0.82998089,  0.73725636, -1.50524799, -0.50126892,
#        -1.34772597,  0.37700764, -0.76273541,  0.45070605, -1.19828703])

# %%
print(test.size)
pylot.plot(test)
pylot.show()
# Out:
# 50

# %%
seaborn.distplot(test, hist=True)
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_5372\3201722898.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   seaborn.distplot(test, hist=True)
# <Axes: ylabel='Density'>

# %% [markdown]
# Generate Data

# %%
data1 = numpy.random.randn(sample1) * sd + rataan1
data2 = numpy.random.randn(sample2) * sd + rataan2
print(sample1, sample2)
print(rataan1, rataan2)
print(sd)

kelompok_data = [sample1, sample2]

batas = [numpy.min(numpy.hstack((data1, data2))), numpy.max(numpy.hstack((data1, data2)))]
batas
# Out:
# 50 40
# 50 65
# 5
# [39.2897118125399, 75.38907185299392]

# %%
pylot.figure(figsize=(7, 5))

a  = seaborn.distplot(data1, hist=False, label="Data 1")
b  = seaborn.distplot(data2, hist=False, label="Data 2")

a.set(xlabel='Data', ylabel='Density')
pylot.grid()
pylot.legend()
pylot.show()
print(data1, f"\nlen: {data1.size}\n", f"min: {numpy.min(data1)}\n", f"max: {numpy.max(data1)}")
print(data2, f"\nlen {data2.size}\n", f"min: {numpy.min(data2)}\n", f"max: {numpy.max(data2)}")
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_5372\2045146540.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   a  = seaborn.distplot(data1, hist=False, label="Data 1")
# C:\Users\User\AppData\Local\Temp\ipykernel_5372\2045146540.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# ...

# %%
fig, ax = pylot.subplots(1, 2, figsize=(7, 5), dpi=150)

ax[0].violinplot(data1)
ax[0].plot(1 + numpy.random.randn(sample1) / 10, data1, 'o', color="green")
ax[0].set_ylim(batas)

ax[1].violinplot(data2)
ax[1].plot(1 + numpy.random.randn(sample2) / 10, data2, 'o', color="blue")
ax[1].set_ylim(batas)

t, p = stat.ttest_ind(data1, data2)

sigtxt = ('', ' Tidak')
pylot.title("Dua Kelompok {} berbeda secara signifikan t({}) = {}, p = {}".format(sigtxt[int(p > .05)], sum(kelompok_data) - 2, numpy.around(t, 2), numpy.around(p, 6)))

pylot.show()
