# %%
import pandas
import numpy

# %%
paal_df = pandas.read_csv('./data/PAAL_ORDER_HISTORY.csv')
paal_df
# Out:
#                          Time       Type Pair          Side    Price  \
# 2024-06-04 20:08:02  Exchange  PAAL/USDT  Buy  Market Price  10.7723
# 2024-06-03 01:26:22  Exchange  PAAL/USDT  Buy  Market Price  10.0000
# 2024-05-31 23:48:01  Exchange  PAAL/USDT  Buy        0.3505  71.3266
# 2024-05-30 23:54:03  Exchange  PAAL/USDT  Buy  Market Price  10.0000
# 2024-05-30 12:32:22  Exchange  PAAL/USDT  Buy        0.3600  27.8055
# 2024-05-29 15:23:56  Exchange  PAAL/USDT  Buy        0.3650  27.4246
# 2024-05-29 00:53:00  Exchange  PAAL/USDT  Buy        0.3800  34.2104
# 2024-05-28 19:29:55  Exchange  PAAL/USDT  Buy  Market Price  15.0000
# 2024-05-27 22:26:36  Exchange  PAAL/USDT  Buy  Market Price  10.0000
# 2024-05-26 14:22:45  Exchange  PAAL/USDT  Buy  Market Price  10.9872
# 2024-05-26 09:22:04  Exchange  PAAL/USDT  Buy        0.4150  24.0987
# 2024-05-25 20:08:46  Exchange  PAAL/USDT  Buy  Market Price  10.0000
# 2024-05-25 13:16:32  Exchange  PAAL/USDT  Buy        0.4300  23.2581
# ...

# %%
amount_buy = [10, 10, 10, 20, 24, 16, 15, 10, 10, 10, 10, 10, 10, 10, 11, 10, 15, 13, 10, 10, 10, 25, 10, 11]
column_name = ["Buy ($)"]

paal_df = pandas.DataFrame(amount_buy, columns=column_name)
print(f"${paal_df.sum()[0]}")
paal_df
# Out:
# $300
# C:\Users\User\AppData\Local\Temp\ipykernel_8348\4267503163.py:5: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   print(f"${paal_df.sum()[0]}")
#     Buy ($)
# 0        10
# 1        10
# 2        10
# 3        20
# 4        24
# 5        16
# 6        15
# 7        10
# 8        10
# 9        10
# 10       10
# 11       10
# 12       10
# 13       10
# 14       11
# 15       10
# 16       15
# 17       13
# 18       10
# 19       10
# 20       10
# 21       25
# 22       10
# 23       11
